# %% [markdown]
# # Exploratory Data Analysis #1

# %% [markdown]
# ### Import libraries

# %%
from pyspark.sql import SparkSession
from pyspark.ml.evaluation import RegressionEvaluator

from pyspark.ml.recommendation import ALS

from pyspark.ml.evaluation import RegressionEvaluator

from pyspark.ml.tuning import CrossValidator, ParamGridBuilder
import pyspark
spark = SparkSession.builder.getOrCreate()

from pyspark.sql.types import IntegerType
from pyspark.sql.functions import isnan, when, count, col
from pyspark.sql.types import *

# %%
import os
import pandas as pd

# %%
# Out:
# ERROR:py4j.java_gateway:An error occurred while trying to connect to the Java server (127.0.0.1:50793)
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 977, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 1115, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 61] Connection refused
# /opt/anaconda3/lib/python3.8/site-packages/pyspark/context.py:451: RuntimeWarning: Unable to cleanly shutdown Spark JVM process. It is possible that the process has crashed, been killed or may also be in a zombie state.
#   warnings.warn(
# ERROR:py4j.java_gateway:An error occurred while trying to connect to the Java server (127.0.0.1:50793)
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 977, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 1115, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 61] Connection refused
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py in _get_connection(self)
#     976         try:
# --> 977             connection = self.deque.pop()
#     978         except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# ConnectionRefusedError                    Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py in start(self)
#    1114         try:
# -> 1115             self.socket.connect((self.address, self.port))
#    1116             self.stream = self.socket.makefile("rb")
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Py4JNetworkError                          Traceback (most recent call last)
# <ipython-input-69-5c6b4d5d9db0> in <module>
# ----> 1 spark.stop()
#
# /opt/anaconda3/lib/python3.8/site-packages/pyspark/sql/session.py in stop(self)
#     705         self._sc.stop()
#     706         # We should clean the default session up. See SPARK-23228.
# --> 707         self._jvm.SparkSession.clearDefaultSession()
#     708         self._jvm.SparkSession.clearActiveSession()
#     709         SparkSession._instantiatedSession = None
#
# /opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py in __getattr__(self, name)
#    1690             return UserHelpAutoCompletion()
#    1691
# -> 1692         answer = self._gateway_client.send_command(
#    1693             proto.REFLECTION_COMMAND_NAME +
#    1694             proto.REFL_GET_UNKNOWN_SUB_COMMAND_NAME + name + "\n" + self._id +
#
# /opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py in send_command(self, command, retry, binary)
#    1029          if `binary` is `True`.
#    1030         """
# -> 1031         connection = self._get_connection()
#    1032         try:
#    1033             response = connection.send_command(command)
#
# /opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py in _get_connection(self)
#     977             connection = self.deque.pop()
#     978         except IndexError:
# --> 979             connection = self._create_connection()
#     980         return connection
#     981
#
# /opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py in _create_connection(self)
#     983         connection = GatewayConnection(
#     984             self.gateway_parameters, self.gateway_property)
# --> 985         connection.start()
#     986         return connection
#     987
#
# /opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py in start(self)
#    1125                 "server ({0}:{1})".format(self.address, self.port)
#    1126             logger.exception(msg)
# -> 1127             raise Py4JNetworkError(msg, e)
#    1128
#    1129     def _authenticate_connection(self):
#
# Py4JNetworkError: An error occurred while trying to connect to the Java server (127.0.0.1:50793)

# %% [markdown]
# ### Import data

# %%
df2 = pd.read_csv('comb_df2.csv')
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82756 entries, 0 to 82755
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   genre             82756 non-null  object
#  1   title             82756 non-null  object
#  2   author            82756 non-null  object
#  3   pages             82756 non-null  int64
#  4   average_rating    82756 non-null  float64
#  5   book_description  62938 non-null  object
#  6   user_unique_key   82756 non-null  int64
#  7   number_of_stars   82756 non-null  int64
#  8   book_unique_key   82756 non-null  int64
#  9   review_text       81263 non-null  object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 6.3+ MB

# %% [markdown]
# ### Inspect the data

# %% [markdown]
# ### Pre-process the data

# %%
#join the tables

# %%
#check for nulls/nans

# %% [markdown]
# ### EDA visualizations

# %% [markdown]
# ### Build first simple model (FSM)

# %%
dfpd= pd.read_csv('comb_df2.csv')

# %%
schema = StructType([StructField("genre", StringType(), True),StructField("title", StringType(), True), 
                     StructField("author", StringType(), True), StructField("pages", IntegerType(), True), 
                     StructField("average_rating", FloatType(), True), StructField("book_description", StringType(), True), 
                     StructField("user_unique_key", IntegerType(), True),StructField("number_of_stars", IntegerType(), True), 
                     StructField("book_unique_key", IntegerType(), True), StructField("review_text", StringType(), True)])

sp_df = spark.createDataFrame(dfpd, schema=schema)
# Out:
# ERROR:py4j.java_gateway:An error occurred while trying to connect to the Java server (127.0.0.1:50793)
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 977, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 1115, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 61] Connection refused
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py in _get_connection(self)
#     976         try:
# --> 977             connection = self.deque.pop()
#     978         except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# ConnectionRefusedError                    Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py in start(self)
#    1114         try:
# -> 1115             self.socket.connect((self.address, self.port))
#    1116             self.stream = self.socket.makefile("rb")
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Py4JNetworkError                          Traceback (most recent call last)
# <ipython-input-66-8d35195fd69b> in <module>
#       5                      StructField("book_unique_key", IntegerType(), True), StructField("review_text", StringType(), True)])
#       6
# ----> 7 sp_df = spark.createDataFrame(dfpd, schema=schema)
#
# /opt/anaconda3/lib/python3.8/site-packages/pyspark/sql/session.py in createDataFrame(self, data, schema, samplingRatio, verifySchema)
#     584         """
#     585         SparkSession._activeSession = self
# --> 586         self._jvm.SparkSession.setActiveSession(self._jsparkSession)
#     587         if isinstance(data, DataFrame):
#     588             raise TypeError("data is already a DataFrame")
#
# /opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py in __getattr__(self, name)
#    1690             return UserHelpAutoCompletion()
#    1691
# -> 1692         answer = self._gateway_client.send_command(
#    1693             proto.REFLECTION_COMMAND_NAME +
#    1694             proto.REFL_GET_UNKNOWN_SUB_COMMAND_NAME + name + "\n" + self._id +
#
# /opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py in send_command(self, command, retry, binary)
#    1029          if `binary` is `True`.
#    1030         """
# -> 1031         connection = self._get_connection()
#    1032         try:
#    1033             response = connection.send_command(command)
#
# /opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py in _get_connection(self)
#     977             connection = self.deque.pop()
#     978         except IndexError:
# --> 979             connection = self._create_connection()
#     980         return connection
#     981
#
# /opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py in _create_connection(self)
#     983         connection = GatewayConnection(
#     984             self.gateway_parameters, self.gateway_property)
# --> 985         connection.start()
#     986         return connection
#     987
#
# /opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py in start(self)
#    1125                 "server ({0}:{1})".format(self.address, self.port)
#    1126             logger.exception(msg)
# -> 1127             raise Py4JNetworkError(msg, e)
#    1128
#    1129     def _authenticate_connection(self):
#
# Py4JNetworkError: An error occurred while trying to connect to the Java server (127.0.0.1:50793)

# %%
sp_df.dtypes
# Out:
# [('genre', 'string'),
#  ('title', 'string'),
#  ('author', 'string'),
#  ('pages', 'int'),
#  ('average_rating', 'float'),
#  ('book_description', 'string'),
#  ('user_unique_key', 'int'),
#  ('number_of_stars', 'int'),
#  ('book_unique_key', 'int'),
#  ('review_text', 'string')]

# %%
sm_df= pd.read_csv('comb_df2.csv')

# %%
schema = StructType([StructField("genre", StringType(), True),StructField("title", StringType(), True), 
                     StructField("author", StringType(), True), StructField("pages", IntegerType(), True), 
                     StructField("average_rating", FloatType(), True), StructField("book_description", StringType(), True), 
                     StructField("user_unique_key", IntegerType(), True),StructField("number_of_stars", IntegerType(), True), 
                     StructField("book_unique_key", IntegerType(), True), StructField("review_text", StringType(), True)])

df_sm2 = spark.createDataFrame(sm_df, schema=schema)

# %%
# pddf = pd.read_csv("comb_df7.csv")
# sp_df = spark.createDataFrame(pd_df, schema=schema)

# %%
# print("The book with the fewest ratings: ")
# out3.groupBy("book_unique_key").count().select(min("count")).show()

# print("Avg num ratings per book: ")
# out3.groupBy("book_unique_key").count().select(avg("count")).show()


# print("User with the fewest ratings: ")
# out3.groupBy("user_unique_key").count().select(min("count")).show()

# print("Avg num ratings per user: ")
# out3.groupBy("user_unique_key").count().select(avg("count")).show()
# Out:
# The book with the fewest ratings:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <ipython-input-92-32d4dce015bc> in <module>
#       1 print("The book with the fewest ratings: ")
# ----> 2 out3.groupBy("book_unique_key").count().select(min("count")).show()
#       3
#       4 # print("Avg num ratings per book: ")
#       5 # out3.groupBy("book_unique_key").count().select(avg("count")).show()
#
# /opt/anaconda3/lib/python3.8/site-packages/pyspark/sql/dataframe.py in select(self, *cols)
#    1419         [Row(name=u'Alice', age=12), Row(name=u'Bob', age=15)]
#    1420         """
# -> 1421         jdf = self._jdf.select(self._jcols(*cols))
#    1422         return DataFrame(jdf, self.sql_ctx)
#    1423
#
# /opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# -> 1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#
# /opt/anaconda3/lib/python3.8/site-packages/pyspark/sql/utils.py in deco(*a, **kw)
#     132                 # Hide where the exception came from that shows a non-Pythonic
#     133                 # JVM exception message.
# --> 134                 raise_from(converted)
#     135             else:
#     136                 raise
#
# /opt/anaconda3/lib/python3.8/site-packages/pyspark/sql/utils.py in raise_from(e)
#
# AnalysisException: cannot resolve '`c`' given input columns: [book_unique_key, count];;
# 'Project ['c]
# +- Aggregate [book_unique_key#1780], [book_unique_key#1780, count(1) AS count#3566L]
#    +- Project [genre#1749, title#1750, author#1751, pages#1752, average_rating#1753, book_description#1754, cast(user_unique_key#1755 as int) AS user_unique_key#1791, number_of_stars#1769, book_unique_key#1780, review_text#1758]
#       +- Project [genre#1749, title#1750, author#1751, pages#1752, average_rating#1753, book_description#1754, user_unique_key#1755, number_of_stars#1769, cast(book_unique_key#1757 as int) AS book_unique_key#1780, review_text#1758]
#          +- Project [genre#1749, title#1750, author#1751, pages#1752, average_rating#1753, book_description#1754, user_unique_key#1755, cast(number_of_stars#1756 as int) AS number_of_stars#1769, book_unique_key#1757, review_text#1758]
#             +- Relation[genre#1749,title#1750,author#1751,pages#1752,average_rating#1753,book_description#1754,user_unique_key#1755,number_of_stars#1756,book_unique_key#1757,review_text#1758] csv

# %% [markdown]
# "sparsity is calculated by the number of cells in a matrix that contain a rating divided by the total number of values that matrix could hold given the number of users and items [such as books]. In other words, dividing the number of ratings present in the matrix by the product of users and [books] in the matrix and subtracting that from 1 will give us the sparsity or the percentage of the ratings matrix that is empty."

# %%
# calculating sparcity--

numerator = out3.select("number_of_stars").count()


num_users = out3.select("user_unique_key").distinct().count()
num_books = out3.select("book_unique_key").distinct().count()


denominator = num_users * num_books


sparsity = (1.0 - (numerator *1.0)/denominator)*100
print("The ratings dataframe is ", "%.2f" % sparsity + "% empty.")
# Out:
# The ratings dataframe is  98.25% empty.

# %%
numerator = df_sm2.select("number_of_stars").count()


num_users = df_sm2.select("user_unique_key").distinct().count()
num_books = df_sm2.select("book_unique_key").distinct().count()


denominator = num_users * num_books


sparsity = (1.0 - (numerator *1.0)/denominator)*100
print("The ratings dataframe is ", "%.2f" % sparsity + "% empty.")
# Out:
# The ratings dataframe is  99.66% empty.

# %%
train, test = df_sm2.randomSplit([0.8, 0.2])

# %%
als = ALS(maxIter=5,rank=4, 
          userCol='user_unique_key', itemCol='book_unique_key', 
          ratingCol='number_of_stars',
          coldStartStrategy='drop')


model_fsm = als.fit(train)

# %%
predictions = model_fsm.transform(test)
evaluator = RegressionEvaluator(metricName='rmse', labelCol='number_of_stars',
                                predictionCol='prediction')
rmse = evaluator.evaluate(predictions)
print('Root-mean-square error = ' + str(rmse))
# Out:
# Root-mean-square error = 2.0223570085417655

# %%
evaluator = RegressionEvaluator(metricName='mae', labelCol='number_of_stars',
                                predictionCol='prediction')
mae = evaluator.evaluate(predictions)
print('mean absolute error = ' + str(mae))
# Out:
# mean absolute error = 1.4622031358310703

# %%
train, test = df_sm2.randomSplit([0.8, 0.2])

# %%
#train, test = df_sm2.randomSplit([0.8, 0.2])
als2 = ALS(maxIter=5,rank=4, 
          userCol='user_unique_key', itemCol='book_unique_key', 
          ratingCol='number_of_stars',
          coldStartStrategy='drop')


model_fsm2 = als2.fit(train)
predictions2 = model_fsm2.transform(test)
predictions2.show()
# Out:
# +-----------+--------------------+--------------------+-----+--------------+--------------------+---------------+---------------+---------------+--------------------+------------+
# |      genre|               title|              author|pages|average_rating|    book_description|user_unique_key|number_of_stars|book_unique_key|         review_text|  prediction|
# +-----------+--------------------+--------------------+-----+--------------+--------------------+---------------+---------------+---------------+--------------------+------------+
# |anthologies|Because You Love ...|Amerie () (Editor...|  368|           3.5|Leave it to the h...|          11119|              4|            148|4.5 ★★★★
#
# Because...|  0.97753716|
# |anthologies|Because You Love ...|Amerie () (Editor...|  368|           3.5|Leave it to the h...|          30855|              4|            148|3.75 stars
# Okay, ...|  0.79014516|
# |anthologies|Because You Love ...|Amerie () (Editor...|  368|           3.5|Leave it to the h...|          30887|              2|            148|Okay...I wanted s...|-0.066880636|
# |anthologies|Because You Love ...|Amerie () (Editor...|  368|           3.5|Leave it to the h...|          28361|              3|            148|Overall, I enjoye...|   2.8402317|
# |anthologies|Because You Love ...|Amerie () (Editor...|  368|           3.5|Leave it to the h...|          22780|              0|            148|I've only read Ci...|    3.441492|
# |anthologies|Because You Love ...|Amerie () (Editor...|  368|           3.5|Leave it to the h...|           3791|              1|            148|"A freaking panto...|  0.26017892|
# |anthologies|Because You Love ...|Amerie () (Editor...|  368|           3.5|Leave it to the h...|          16355|              4|            148|                 NaN|    1.859171|
# |anthologies|Because You Love ...|Amerie () (Editor...|  368|           3.5|Leave it to the h...|          16645|              3|            148|Thank-you to Bloo...|   1.0447766|
# |anthologies|Because You Love ...|Amerie () (Editor...|  368|           3.5|Leave it to the h...|          21890|              3|            148|I was looking for...|   1.1333392|
# |anthologies|Because You Love ...|Amerie () (Editor...|  368|           3.5|Leave it to the h...|          15530|              4|            148|3.5 Stars!
#
# I don...|   1.8467035|
# |anthologies|Because You Love ...|Amerie () (Editor...|  368|           3.5|Leave it to the h...|           6798|              4|            148|This was fun! The...|   2.5445163|
# |anthologies|Because You Love ...|Amerie () (Editor...|  368|           3.5|Leave it to the h...|          18628|              3|            148|3.384/5 stars
#
# Vi...|     2.33886|
# |anthologies|Because You Love ...|Amerie () (Editor...|  368|           3.5|Leave it to the h...|          19648|              3|            148|The average ratin...|   1.4424067|
# |anthologies|Because You Love ...|Amerie () (Editor...|  368|           3.5|Leave it to the h...|          12378|              0|            148|I just don't thin...|   2.7904382|
# |anthologies|Because You Love ...|Amerie () (Editor...|  368|           3.5|Leave it to the h...|          38473|              5|            148|SO INCREDIBLY EXC...|   3.3385181|
# |anthologies|Because You Love ...|Amerie () (Editor...|  368|           3.5|Leave it to the h...|          25549|              3|            148|I thought, going ...|   0.8567698|
# |anthologies|Because You Love ...|Amerie () (Editor...|  368|           3.5|Leave it to the h...|          13956|              2|            148|The anthology's s...|   2.1822412|
# |anthologies|Because You Love ...|Amerie () (Editor...|  368|           3.5|Leave it to the h...|          10701|              0|            148|There's Schwab an...|   2.1030762|
# |anthologies|Because You Love ...|Amerie () (Editor...|  368|           3.5|Leave it to the h...|          24206|              1|            148|It's clear (...an...|  0.88063604|
# |anthologies|Because You Love ...|Amerie () (Editor...|  368|           3.5|Leave it to the h...|          16252|              3|            148|I enjoyed 6 out o...|   1.5337338|
# +-----------+--------------------+--------------------+-----+--------------+--------------------+---------------+---------------+---------------+--------------------+------------+
# only showing top 20 rows

# %%
predictions2 = model_fsm2.transform(test)
evaluator2 = RegressionEvaluator(metricName='rmse', labelCol='number_of_stars',
                                predictionCol='prediction')
rmse2 = evaluator2.evaluate(predictions2)
print('Root-mean-square error = ' + str(rmse2))
# Out:
# Root-mean-square error = 2.0971997522129304

# %%
evaluator3 = RegressionEvaluator(metricName='mae', labelCol='number_of_stars',
                                predictionCol='prediction')
mae2 = evaluator3.evaluate(predictions2)
print('mean absolute error = ' + str(mae2))
# Out:
# mean absolute error = 1.4678074366732219

# %%
train, test = df_sm2.randomSplit([0.8, 0.2])

# %%
als_model = ALS(userCol='user_unique_key', itemCol='book_unique_key',ratingCol='number_of_stars', 
                rank=10  , maxIter=20 , regParam=.05,
                nonnegative=True,implicitPrefs=False, 
                coldStartStrategy='drop')
model4 = als_model.fit(train)
pred = model4.transform(test)
pred.show()
# Out:
# +-----------+--------------------+--------------------+-----+--------------+--------------------+---------------+---------------+---------------+--------------------+----------+
# |      genre|               title|              author|pages|average_rating|    book_description|user_unique_key|number_of_stars|book_unique_key|         review_text|prediction|
# +-----------+--------------------+--------------------+-----+--------------+--------------------+---------------+---------------+---------------+--------------------+----------+
# |anthologies|Because You Love ...|Amerie () (Editor...|  368|           3.5|Leave it to the h...|          11119|              4|            148|4.5 ★★★★
#
# Because...|0.81286174|
# |anthologies|Because You Love ...|Amerie () (Editor...|  368|           3.5|Leave it to the h...|          30855|              4|            148|3.75 stars
# Okay, ...|  1.579124|
# |anthologies|Because You Love ...|Amerie () (Editor...|  368|           3.5|Leave it to the h...|          30887|              2|            148|Okay...I wanted s...| 2.6131527|
# |anthologies|Because You Love ...|Amerie () (Editor...|  368|           3.5|Leave it to the h...|          28361|              3|            148|Overall, I enjoye...|  2.565959|
# |anthologies|Because You Love ...|Amerie () (Editor...|  368|           3.5|Leave it to the h...|          22780|              0|            148|I've only read Ci...|  3.045713|
# |anthologies|Because You Love ...|Amerie () (Editor...|  368|           3.5|Leave it to the h...|           3791|              1|            148|"A freaking panto...| 2.5448275|
# |anthologies|Because You Love ...|Amerie () (Editor...|  368|           3.5|Leave it to the h...|          16355|              4|            148|                 NaN| 2.8310761|
# |anthologies|Because You Love ...|Amerie () (Editor...|  368|           3.5|Leave it to the h...|          16645|              3|            148|Thank-you to Bloo...| 2.7083197|
# |anthologies|Because You Love ...|Amerie () (Editor...|  368|           3.5|Leave it to the h...|          21890|              3|            148|I was looking for...| 3.8519723|
# |anthologies|Because You Love ...|Amerie () (Editor...|  368|           3.5|Leave it to the h...|          15530|              4|            148|3.5 Stars!
#
# I don...| 1.9038577|
# |anthologies|Because You Love ...|Amerie () (Editor...|  368|           3.5|Leave it to the h...|           6798|              4|            148|This was fun! The...|   2.04051|
# |anthologies|Because You Love ...|Amerie () (Editor...|  368|           3.5|Leave it to the h...|          18628|              3|            148|3.384/5 stars
#
# Vi...| 2.1088004|
# |anthologies|Because You Love ...|Amerie () (Editor...|  368|           3.5|Leave it to the h...|          19648|              3|            148|The average ratin...|  2.671576|
# |anthologies|Because You Love ...|Amerie () (Editor...|  368|           3.5|Leave it to the h...|          12378|              0|            148|I just don't thin...|  3.934947|
# |anthologies|Because You Love ...|Amerie () (Editor...|  368|           3.5|Leave it to the h...|          38473|              5|            148|SO INCREDIBLY EXC...| 3.8803859|
# |anthologies|Because You Love ...|Amerie () (Editor...|  368|           3.5|Leave it to the h...|          25549|              3|            148|I thought, going ...| 1.5476601|
# |anthologies|Because You Love ...|Amerie () (Editor...|  368|           3.5|Leave it to the h...|          13956|              2|            148|The anthology's s...|  2.322295|
# |anthologies|Because You Love ...|Amerie () (Editor...|  368|           3.5|Leave it to the h...|          10701|              0|            148|There's Schwab an...|  3.183084|
# |anthologies|Because You Love ...|Amerie () (Editor...|  368|           3.5|Leave it to the h...|          24206|              1|            148|It's clear (...an...|0.09825931|
# |anthologies|Because You Love ...|Amerie () (Editor...|  368|           3.5|Leave it to the h...|          16252|              3|            148|I enjoyed 6 out o...|0.23606865|
# +-----------+--------------------+--------------------+-----+--------------+--------------------+---------------+---------------+---------------+--------------------+----------+
# only showing top 20 rows

# %%
evaluator4 = RegressionEvaluator(metricName='rmse', labelCol='number_of_stars',
                                predictionCol='prediction')
rmse4 = evaluator4.evaluate(pred)
print('Root-mean-square error = ' + str(rmse4))
# Out:
# Root-mean-square error = 1.6117768320108463

# %%
train, test = df_sm2.randomSplit([0.8, 0.2])
# Out:
# ERROR:py4j.java_gateway:An error occurred while trying to connect to the Java server (127.0.0.1:50793)
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 977, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 1115, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 61] Connection refused
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py in _get_connection(self)
#     976         try:
# --> 977             connection = self.deque.pop()
#     978         except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# ConnectionRefusedError                    Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py in start(self)
#    1114         try:
# -> 1115             self.socket.connect((self.address, self.port))
#    1116             self.stream = self.socket.makefile("rb")
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Py4JNetworkError                          Traceback (most recent call last)
# <ipython-input-49-5a5949f07faf> in <module>
# ----> 1 train, test = df_sm2.randomSplit([0.8, 0.2])
#
# /opt/anaconda3/lib/python3.8/site-packages/pyspark/sql/dataframe.py in randomSplit(self, weights, seed)
#    1009                 raise ValueError("Weights must be positive. Found weight value: %s" % w)
#    1010         seed = seed if seed is not None else random.randint(0, sys.maxsize)
# -> 1011         rdd_array = self._jdf.randomSplit(_to_list(self.sql_ctx._sc, weights), long(seed))
#    1012         return [DataFrame(rdd, self.sql_ctx) for rdd in rdd_array]
#    1013
#
# /opt/anaconda3/lib/python3.8/site-packages/pyspark/sql/column.py in _to_list(sc, cols, converter)
#      79     if converter:
#      80         cols = [converter(c) for c in cols]
# ---> 81     return sc._jvm.PythonUtils.toList(cols)
#      82
#      83
#
# /opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py in __getattr__(self, name)
#    1690             return UserHelpAutoCompletion()
#    1691
# -> 1692         answer = self._gateway_client.send_command(
#    1693             proto.REFLECTION_COMMAND_NAME +
#    1694             proto.REFL_GET_UNKNOWN_SUB_COMMAND_NAME + name + "\n" + self._id +
#
# /opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py in send_command(self, command, retry, binary)
#    1029          if `binary` is `True`.
#    1030         """
# -> 1031         connection = self._get_connection()
#    1032         try:
#    1033             response = connection.send_command(command)
#
# /opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py in _get_connection(self)
#     977             connection = self.deque.pop()
#     978         except IndexError:
# --> 979             connection = self._create_connection()
#     980         return connection
#     981
#
# /opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py in _create_connection(self)
#     983         connection = GatewayConnection(
#     984             self.gateway_parameters, self.gateway_property)
# --> 985         connection.start()
#     986         return connection
#     987
#
# /opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py in start(self)
#    1125                 "server ({0}:{1})".format(self.address, self.port)
#    1126             logger.exception(msg)
# -> 1127             raise Py4JNetworkError(msg, e)
#    1128
#    1129     def _authenticate_connection(self):
#
# Py4JNetworkError: An error occurred while trying to connect to the Java server (127.0.0.1:50793)

# %%
train, test = df_sm2.randomSplit([0.8, 0.2])
als_modelv = ALS(userCol='user_unique_key', itemCol='book_unique_key',ratingCol='number_of_stars',
                nonnegative=True,implicitPrefs=False, 
                coldStartStrategy='drop')

modelv = als_modelv.fit(train)
pred = modelv.transform(test)
                
evaluatorv = RegressionEvaluator(metricName='rmse', labelCol='number_of_stars',
                                predictionCol='prediction')
params=ParamGridBuilder()
params = ParamGridBuilder().addGrid(als_modelv.regParam, [0.01, 0.05, .1, 1.5]) \
        .addGrid(als_modelv.rank, [4, 10, 30, 70]) \
        .addGrid(als_modelv.maxIter, [5, 15, 30, 45, 75]).build()
    
cv= CrossValidator()
crossval = CrossValidator(estimator=als_modelv, 
                          estimatorParamMaps=params,
                          evaluator=evaluatorv,
                          numFolds= 6)
modelv= crossval.fit(train)    

best_model = modelv.bestModel

# best_model.bestModel.rank
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-7-23baf0d3297a> in <module>
#      19                           evaluator=evaluatorv,
#      20                           numFolds= 6)
# ---> 21 modelv= crossval.fit(train)
#      22
#      23 best_model = modelv.bestModel
#
# /opt/anaconda3/lib/python3.8/site-packages/pyspark/ml/base.py in fit(self, dataset, params)
#     127                 return self.copy(params)._fit(dataset)
#     128             else:
# --> 129                 return self._fit(dataset)
#     130         else:
#     131             raise ValueError("Params must be either a param map or a list/tuple of param maps, "
#
# /opt/anaconda3/lib/python3.8/site-packages/pyspark/ml/tuning.py in _fit(self, dataset)
#     356
#     357             tasks = _parallelFitTasks(est, train, eva, validation, epm, collectSubModelsParam)
# --> 358             for j, metric, subModel in pool.imap_unordered(lambda f: f(), tasks):
#     359                 metrics[j] += (metric / nFolds)
#     360                 if collectSubModelsParam:
#
# /opt/anaconda3/lib/python3.8/multiprocessing/pool.py in next(self, timeout)
#     866         if success:
#     867             return value
# --> 868         raise value
#     869
#     870     __next__ = next                    # XXX
#
# /opt/anaconda3/lib/python3.8/multiprocessing/pool.py in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     123         job, i, func, args, kwds = task
#     124         try:
# --> 125             result = (True, func(*args, **kwds))
#     126         except Exception as e:
#     127             if wrap_exception and func is not _helper_reraises_exception:
#
# /opt/anaconda3/lib/python3.8/site-packages/pyspark/ml/tuning.py in <lambda>(f)
#     356
#     357             tasks = _parallelFitTasks(est, train, eva, validation, epm, collectSubModelsParam)
# --> 358             for j, metric, subModel in pool.imap_unordered(lambda f: f(), tasks):
#     359                 metrics[j] += (metric / nFolds)
#     360                 if collectSubModelsParam:
#
# /opt/anaconda3/lib/python3.8/site-packages/pyspark/ml/tuning.py in singleTask()
#      50
#      51     def singleTask():
# ---> 52         index, model = next(modelIter)
#      53         metric = eva.evaluate(model.transform(validation, epm[index]))
#      54         return index, metric, model if collectSubModel else None
#
# /opt/anaconda3/lib/python3.8/site-packages/pyspark/ml/base.py in __next__(self)
#      60                 raise StopIteration("No models remaining.")
#      61             self.counter += 1
# ---> 62         return index, self.fitSingleModel(index)
#      63
#      64     def next(self):
#
# /opt/anaconda3/lib/python3.8/site-packages/pyspark/ml/base.py in fitSingleModel(index)
#     101
#     102         def fitSingleModel(index):
# --> 103             return estimator.fit(dataset, paramMaps[index])
#     104
#     105         return _FitMultipleIterator(fitSingleModel, len(paramMaps))
#
# /opt/anaconda3/lib/python3.8/site-packages/pyspark/ml/base.py in fit(self, dataset, params)
#     125         elif isinstance(params, dict):
#     126             if params:
# --> 127                 return self.copy(params)._fit(dataset)
#     128             else:
#     129                 return self._fit(dataset)
#
# /opt/anaconda3/lib/python3.8/site-packages/pyspark/ml/wrapper.py in _fit(self, dataset)
#     319
#     320     def _fit(self, dataset):
# --> 321         java_model = self._fit_java(dataset)
#     322         model = self._create_model(java_model)
#     323         return self._copyValues(model)
#
# /opt/anaconda3/lib/python3.8/site-packages/pyspark/ml/wrapper.py in _fit_java(self, dataset)
#     316         """
#     317         self._transfer_params_to_java()
# --> 318         return self._java_obj.fit(dataset._jdf)
#     319
#     320     def _fit(self, dataset):
#
# /opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# -> 1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#
# /opt/anaconda3/lib/python3.8/site-packages/pyspark/sql/utils.py in deco(*a, **kw)
#     126     def deco(*a, **kw):
#     127         try:
# --> 128             return f(*a, **kw)
#     129         except py4j.protocol.Py4JJavaError as e:
#     130             converted = convert_exception(e.java_exception)
#
# /opt/anaconda3/lib/python3.8/site-packages/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     324             value = OUTPUT_CONVERTER[type](answer[2:], gateway_client)
#     325             if answer[1] == REFERENCE_TYPE:
# --> 326                 raise Py4JJavaError(
#     327                     "An error occurred while calling {0}{1}{2}.\n".
#     328                     format(target_id, ".", name), value)
#
# Py4JJavaError: An error occurred while calling o641.fit.
# : org.apache.spark.SparkException: Job aborted due to stage failure: Task 3 in stage 289.0 failed 1 times, most recent failure: Lost task 3.0 in stage 289.0 (TID 2730, 10.0.0.8, executor driver): java.lang.StackOverflowError
# 	at java.io.ObjectInputStream$BlockDataInputStream.readByte(ObjectInputStream.java:3244)
# 	at java.io.ObjectInputStream.readArray(ObjectInputStream.java:2044)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1655)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:503)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:461)
# 	at scala.collection.immutable.List$SerializationProxy.readObject(List.scala:488)
# 	at sun.reflect.GeneratedMethodAccessor26.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at java.io.ObjectStreamClass.invokeReadObject(ObjectStreamClass.java:1184)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2296)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:503)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:461)
# 	at scala.collection.immutable.List$SerializationProxy.readObject(List.scala:488)
# 	at sun.reflect.GeneratedMethodAccessor26.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at java.io.ObjectStreamClass.invokeReadObject(ObjectStreamClass.java:1184)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2296)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:503)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:461)
# 	at scala.collection.immutable.List$SerializationProxy.readObject(List.scala:488)
# 	at sun.reflect.GeneratedMethodAccessor26.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at java.io.ObjectStreamClass.invokeReadObject(ObjectStreamClass.java:1184)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2296)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:503)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:461)
# 	at scala.collection.immutable.List$SerializationProxy.readObject(List.scala:488)
# 	at sun.reflect.GeneratedMethodAccessor26.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at java.io.ObjectStreamClass.invokeReadObject(ObjectStreamClass.java:1184)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2296)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:503)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:461)
# 	at scala.collection.immutable.List$SerializationProxy.readObject(List.scala:488)
# 	at sun.reflect.GeneratedMethodAccessor26.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at java.io.ObjectStreamClass.invokeReadObject(ObjectStreamClass.java:1184)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2296)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:503)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:461)
# 	at scala.collection.immutable.List$SerializationProxy.readObject(List.scala:488)
# 	at sun.reflect.GeneratedMethodAccessor26.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at java.io.ObjectStreamClass.invokeReadObject(ObjectStreamClass.java:1184)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2296)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:503)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:461)
# 	at scala.collection.immutable.List$SerializationProxy.readObject(List.scala:488)
# 	at sun.reflect.GeneratedMethodAccessor26.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at java.io.ObjectStreamClass.invokeReadObject(ObjectStreamClass.java:1184)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2296)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:503)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:461)
# 	at scala.collection.immutable.List$SerializationProxy.readObject(List.scala:488)
# 	at sun.reflect.GeneratedMethodAccessor26.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at java.io.ObjectStreamClass.invokeReadObject(ObjectStreamClass.java:1184)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2296)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:503)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:461)
# 	at scala.collection.immutable.List$SerializationProxy.readObject(List.scala:488)
# 	at sun.reflect.GeneratedMethodAccessor26.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at java.io.ObjectStreamClass.invokeReadObject(ObjectStreamClass.java:1184)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2296)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.readArray(ObjectInputStream.java:2093)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1655)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:503)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:461)
# 	at scala.collection.immutable.List$SerializationProxy.readObject(List.scala:488)
# 	at sun.reflect.GeneratedMethodAccessor26.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at java.io.ObjectStreamClass.invokeReadObject(ObjectStreamClass.java:1184)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2296)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:503)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:461)
# 	at scala.collection.immutable.List$SerializationProxy.readObject(List.scala:488)
# 	at sun.reflect.GeneratedMethodAccessor26.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at java.io.ObjectStreamClass.invokeReadObject(ObjectStreamClass.java:1184)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2296)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:503)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:461)
# 	at scala.collection.immutable.List$SerializationProxy.readObject(List.scala:488)
# 	at sun.reflect.GeneratedMethodAccessor26.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at java.io.ObjectStreamClass.invokeReadObject(ObjectStreamClass.java:1184)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2296)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:503)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:461)
# 	at scala.collection.immutable.List$SerializationProxy.readObject(List.scala:488)
# 	at sun.reflect.GeneratedMethodAccessor26.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at java.io.ObjectStreamClass.invokeReadObject(ObjectStreamClass.java:1184)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2296)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:503)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:461)
# 	at scala.collection.immutable.List$SerializationProxy.readObject(List.scala:488)
# 	at sun.reflect.GeneratedMethodAccessor26.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at java.io.ObjectStreamClass.invokeReadObject(ObjectStreamClass.java:1184)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2296)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:503)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:461)
# 	at scala.collection.immutable.List$SerializationProxy.readObject(List.scala:488)
# 	at sun.reflect.GeneratedMethodAccessor26.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at java.io.ObjectStreamClass.invokeReadObject(ObjectStreamClass.java:1184)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2296)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:503)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:461)
# 	at scala.collection.immutable.List$SerializationProxy.readObject(List.scala:488)
# 	at sun.reflect.GeneratedMethodAccessor26.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at java.io.ObjectStreamClass.invokeReadObject(ObjectStreamClass.java:1184)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2296)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:503)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:461)
# 	at scala.collection.immutable.List$SerializationProxy.readObject(List.scala:488)
# 	at sun.reflect.GeneratedMethodAccessor26.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at java.io.ObjectStreamClass.invokeReadObject(ObjectStreamClass.java:1184)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2296)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:503)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:461)
# 	at scala.collection.immutable.List$SerializationProxy.readObject(List.scala:488)
# 	at sun.reflect.GeneratedMethodAccessor26.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at java.io.ObjectStreamClass.invokeReadObject(ObjectStreamClass.java:1184)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2296)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.readArray(ObjectInputStream.java:2093)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1655)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:503)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:461)
# 	at scala.collection.immutable.List$SerializationProxy.readObject(List.scala:488)
# 	at sun.reflect.GeneratedMethodAccessor26.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at java.io.ObjectStreamClass.invokeReadObject(ObjectStreamClass.java:1184)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2296)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:503)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:461)
# 	at scala.collection.immutable.List$SerializationProxy.readObject(List.scala:488)
# 	at sun.reflect.GeneratedMethodAccessor26.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at java.io.ObjectStreamClass.invokeReadObject(ObjectStreamClass.java:1184)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2296)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:503)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:461)
# 	at scala.collection.immutable.List$SerializationProxy.readObject(List.scala:488)
# 	at sun.reflect.GeneratedMethodAccessor26.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at java.io.ObjectStreamClass.invokeReadObject(ObjectStreamClass.java:1184)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2296)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:503)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:461)
# 	at scala.collection.immutable.List$SerializationProxy.readObject(List.scala:488)
# 	at sun.reflect.GeneratedMethodAccessor26.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at java.io.ObjectStreamClass.invokeReadObject(ObjectStreamClass.java:1184)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2296)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:503)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:461)
# 	at scala.collection.immutable.List$SerializationProxy.readObject(List.scala:488)
# 	at sun.reflect.GeneratedMethodAccessor26.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at java.io.ObjectStreamClass.invokeReadObject(ObjectStreamClass.java:1184)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2296)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:503)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:461)
# 	at scala.collection.immutable.List$SerializationProxy.readObject(List.scala:488)
# 	at sun.reflect.GeneratedMethodAccessor26.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at java.io.ObjectStreamClass.invokeReadObject(ObjectStreamClass.java:1184)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2296)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:503)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:461)
# 	at scala.collection.immutable.List$SerializationProxy.readObject(List.scala:488)
# 	at sun.reflect.GeneratedMethodAccessor26.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at java.io.ObjectStreamClass.invokeReadObject(ObjectStreamClass.java:1184)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2296)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:503)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:461)
# 	at scala.collection.immutable.List$SerializationProxy.readObject(List.scala:488)
# 	at sun.reflect.GeneratedMethodAccessor26.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at java.io.ObjectStreamClass.invokeReadObject(ObjectStreamClass.java:1184)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2296)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:503)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:461)
# 	at scala.collection.immutable.List$SerializationProxy.readObject(List.scala:488)
# 	at sun.reflect.GeneratedMethodAccessor26.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at java.io.ObjectStreamClass.invokeReadObject(ObjectStreamClass.java:1184)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2296)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.readArray(ObjectInputStream.java:2093)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1655)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:503)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:461)
# 	at scala.collection.immutable.List$SerializationProxy.readObject(List.scala:488)
# 	at sun.reflect.GeneratedMethodAccessor26.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at java.io.ObjectStreamClass.invokeReadObject(ObjectStreamClass.java:1184)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2296)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2405)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2329)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2187)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1667)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:503)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:461)
# ...
# ERROR:py4j.java_gateway:An error occurred while trying to connect to the Java server (127.0.0.1:52229)
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 977, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 1115, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 61] Connection refused
# ERROR:py4j.java_gateway:An error occurred while trying to connect to the Java server (127.0.0.1:52229)
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 977, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 1115, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 61] Connection refused
# ERROR:py4j.java_gateway:An error occurred while trying to connect to the Java server (127.0.0.1:52229)
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 977, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 1115, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 61] Connection refused
# ERROR:py4j.java_gateway:An error occurred while trying to connect to the Java server (127.0.0.1:52229)
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 977, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 1115, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 61] Connection refused
# ERROR:py4j.java_gateway:An error occurred while trying to connect to the Java server (127.0.0.1:52229)
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 977, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 1115, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 61] Connection refused
# ERROR:py4j.java_gateway:An error occurred while trying to connect to the Java server (127.0.0.1:52229)
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 977, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 1115, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 61] Connection refused
# ERROR:py4j.java_gateway:An error occurred while trying to connect to the Java server (127.0.0.1:52229)
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 977, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 1115, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 61] Connection refused
# ERROR:py4j.java_gateway:An error occurred while trying to connect to the Java server (127.0.0.1:52229)
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 977, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 1115, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 61] Connection refused
# ERROR:py4j.java_gateway:An error occurred while trying to connect to the Java server (127.0.0.1:52229)
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 977, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 1115, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 61] Connection refused
# ERROR:py4j.java_gateway:An error occurred while trying to connect to the Java server (127.0.0.1:52229)
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 977, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 1115, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 61] Connection refused
# ERROR:py4j.java_gateway:An error occurred while trying to connect to the Java server (127.0.0.1:52229)
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 977, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 1115, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 61] Connection refused
# ERROR:py4j.java_gateway:An error occurred while trying to connect to the Java server (127.0.0.1:52229)
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 977, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 1115, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 61] Connection refused
# ERROR:py4j.java_gateway:An error occurred while trying to connect to the Java server (127.0.0.1:52229)
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 977, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 1115, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 61] Connection refused
# ERROR:py4j.java_gateway:An error occurred while trying to connect to the Java server (127.0.0.1:52229)
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 977, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 1115, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 61] Connection refused
# ERROR:py4j.java_gateway:An error occurred while trying to connect to the Java server (127.0.0.1:52229)
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 977, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 1115, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 61] Connection refused
# ERROR:py4j.java_gateway:An error occurred while trying to connect to the Java server (127.0.0.1:52229)
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 977, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 1115, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 61] Connection refused
# ERROR:py4j.java_gateway:An error occurred while trying to connect to the Java server (127.0.0.1:52229)
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 977, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 1115, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 61] Connection refused
# ERROR:py4j.java_gateway:An error occurred while trying to connect to the Java server (127.0.0.1:52229)
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 977, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 1115, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 61] Connection refused
# ERROR:py4j.java_gateway:An error occurred while trying to connect to the Java server (127.0.0.1:52229)
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 977, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 1115, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 61] Connection refused
# ERROR:py4j.java_gateway:An error occurred while trying to connect to the Java server (127.0.0.1:52229)
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 977, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 1115, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 61] Connection refused
# ERROR:py4j.java_gateway:An error occurred while trying to connect to the Java server (127.0.0.1:52229)
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 977, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 1115, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 61] Connection refused
# ERROR:py4j.java_gateway:An error occurred while trying to connect to the Java server (127.0.0.1:52229)
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 977, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 1115, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 61] Connection refused
# ERROR:py4j.java_gateway:An error occurred while trying to connect to the Java server (127.0.0.1:52229)
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 977, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 1115, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 61] Connection refused
# ERROR:py4j.java_gateway:An error occurred while trying to connect to the Java server (127.0.0.1:52229)
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 977, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 1115, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 61] Connection refused
# ERROR:py4j.java_gateway:An error occurred while trying to connect to the Java server (127.0.0.1:52229)
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 977, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 1115, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 61] Connection refused
# ERROR:py4j.java_gateway:An error occurred while trying to connect to the Java server (127.0.0.1:52229)
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 977, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/py4j/java_gateway.py", line 1115, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 61] Connection refused

# %%
best
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-377027ff61a3> in <module>
# ----> 1 best
#
# NameError: name 'best' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-2bffbb797b12> in <module>
# ----> 1 best_model.bestModel.rank
#
# AttributeError: 'ALSModel' object has no attribute 'bestModel'

# %%
best_model.HasMaxIter
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-8360fab85bac> in <module>
# ----> 1 best_model.HasMaxIter
#
# AttributeError: 'ALSModel' object has no attribute 'HasMaxIter'

# %%
best_model.maxIter
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-04e3f8584ae8> in <module>
# ----> 1 best_model.maxIter
#
# AttributeError: 'ALSModel' object has no attribute 'maxIter'

# %% [markdown]
# Does it work? do the recommendations make sense?

# %% [markdown]
# "when ALS generates recommendations, they are provided in descending order by userId, so there's no need to sort the dataframe."

# %%
origin_rating =
recommended=
print("User #25 Ratings:")
origin_ratings.filter(col("user_unique_key") == 60).sort("number_of_stars", ascending= False).show()


print("User 300 Recommendations:")
recommended.filter(col("user_unique_key") == 300).show()
